# %% [markdown]
# # Problem Set 1
# ##Alumnos: Estefanía Capriata y Anzony Quispe

# %% [markdown]
# Ejercicio 1

# %%
import pandas as pd

# %%
# Lee el archivo y le pone nombre 'df' al DataFrame
df = pd.read_csv('tarea.csv')

# %%
# Lee las primeras 5 filas
df.head(n=5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Ejercicio 2

# %%
# Lee las primeras 3 filas
df = pd.read_csv('tarea.csv', nrows=3)
df
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5     55    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8     61    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9     65    327  4.05  4.07  2.31

# %% [markdown]
# Ejercicio 3

# %%
# Volvemos al csv completo
df = pd.read_csv('tarea.csv')

# %%
# Imprimir el contenido de una columna como serie
series = df.iloc[:,0]
print(series)
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %% [markdown]
# Ejercicio 4

# %%
# Serie 'calidad-color'
df['Quality–color'] = df.cut + ', ' + df.color
print(df.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality–color
# 0      Ideal, E
# 1    Premium, E
# 2       Good, E
# 3    Premium, I
# 4       Good, J

# %% [markdown]
# Ejercicio 5

# %%
# Número de filas y columnas
df.shape
# Out:
# (53940, 11)

# %%
# Tipo de datos de las columnas
df.dtypes
# Out:
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# Quality–color     object
# dtype: object

# %% [markdown]
# Ejercicio 6

# %%
# Resume solo columnas 'objeto'
df.describe(include=['object'])
# Out:
#           cut  color clarity Quality–color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1      Ideal, G
# freq    21551  11292   13065          4884

# %% [markdown]
# Ejercicio 7

# %%
# Imprimir el 'antes'
print(df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality–color
# 0          Ideal, E
# ...

# %%
# Renombra dos columnas
df = df.rename(columns = {'cut':'quality', 'price':'cost'}, inplace = True)

# %%
# Imprimir el "después"
print(df)
# Out:
#        carat    quality color clarity  depth  table  cost     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0   326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0   326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0   327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0   334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0   335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  2757  5.83  5.87  3.64
#
#       Quality–color
# 0          Ideal, E
# ...

# %% [markdown]
# Ejercicio 8

# %%
# Volvemos al archivo de antes
df = pd.read_csv('tarea.csv')

# %%
# Eliminar segunda y tercera columna (suponiendo que el index es una columna)
df.drop(columns=['carat', 'cut'])
# Out:
#       color clarity  depth  table  price     x     y     z
# 0         E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1         E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2         E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3         I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4         J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...     ...     ...    ...    ...    ...   ...   ...   ...
# 53935     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %% [markdown]
# Ejercicio 9

# %%
# Volvemos al archivo de antes
df = pd.read_csv('tarea.csv')

# %%
# Elimina múltiples filas a la vez
df.drop(labels=[0, 1, 2, 3], axis=0, inplace=False)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94   NaN  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53936 rows x 10 columns]

# %% [markdown]
# Ejercicio 10

# %%
# Ordena a la columna "cut" de manera ascendente
df.sort_values('cut', axis = 0, ascending = True, inplace = True, na_position ='last')

# %%
# Qué tipo de objeto es 'cut'
df = pd.read_csv('tarea.csv')
tipo = df['cut'].dtype
print(tipo)
# Out:
# object

# %% [markdown]
# Ejercicio 11

# %%
# Ordena a la columna "cut" de manera descendente
df.sort_values(by=['carat'], ascending=False)
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 31592   0.20  Premium     E     VS2   59.0   60.0    367   3.81   3.78  2.24
# 31591   0.20  Premium     E     VS2   59.8   62.0    367   3.79   3.77  2.26
# 31601   0.20  Premium     D     VS2   61.7   60.0    367   3.77   3.72  2.31
# 14      0.20  Premium     E     SI2   60.2   62.0    345   3.79   3.75  2.27
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
#
# [53940 rows x 10 columns]

# %% [markdown]
# Ejercicio 12

# %%
# Borra filas según los valores de x, y y z (todos mayores a 5)
df.loc[(df['x'] > 5) & (df['y'] > 5) & (df['z'] > 5)]
# Out:
#        carat        cut color clarity  depth  table  price     x      y      z
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28   5.12
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70   5.36
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95   5.23
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56   5.04
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02   5.36
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...    ...
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97   5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47   5.16
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15  31.80
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80   5.12
# 49905   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04   5.06
#
# ...

# %%
# O también
df[(df['x'] > 5) & (df['y'] > 5) & (df['z'] > 5)]
# Out:
#        carat        cut color clarity  depth  table  price     x      y      z
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28   5.12
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70   5.36
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95   5.23
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56   5.04
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02   5.36
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...    ...
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97   5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47   5.16
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15  31.80
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80   5.12
# 49905   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04   5.06
#
# ...

# %% [markdown]
# Ejercicio 13

# %%
# Filtrar las filas para que sólo muestren 'carat' mayor a 0,4 
for dato in df.carat:
    if dato > 0.4:
        print(dato)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 0.51
# 0.71
# 0.57
# 0.7
# 0.7
# 0.7
# 0.7
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.7
# 0.7
# 0.55
# 0.55
# 0.55
# 0.55
# 0.55
# 0.55
# 0.58
# 0.58
# 0.73
# 0.51
# 0.57
# 0.5
# 0.56
# 0.61
# 0.61
# 0.58
# 0.7
# 0.71
# 0.51
# 0.5
# 0.74
# 0.66
# 0.52
# 0.59
# 0.56
# 0.66
# 0.7
# 0.58
# 0.71
# 0.7
# 0.56
# 0.58
# 0.58
# 0.51
# 0.55
# 0.55
# 0.55
# 0.55
# 0.5
# 0.5
# 0.75
# 0.67
# 0.55
# 0.54
# 0.66
# 0.52
# 0.57
# 0.56
# 0.54
# 0.7
# 0.7
# 0.71
# 0.57
# 0.54
# 0.57
# 0.59
# 0.74
# 0.7
# 0.7
# 0.54
# 0.61
# 0.58
# 0.54
# 0.6
# 0.58
# 0.58
# 0.58
# 0.58
# 0.58
# 0.58
# 0.76
# 0.54
# 0.54
# 0.54
# 0.54
# 0.54
# 0.54
# 0.51
# 0.74
# 0.59
# 0.55
# 0.71
# 0.73
# 0.51
# 0.71
# 0.54
# 0.46
# 0.46
# 0.7
# 0.5
# 0.5
# 0.72
# 0.5
# 0.72
# 0.54
# 0.52
# 0.7
# 0.61
# 0.72
# 0.74
# 0.65
# 0.54
# 0.51
# 0.55
# 0.7
# 0.58
# 0.67
# 0.53
# 0.7
# 0.63
# 0.71
# 0.64
# 0.56
# ...

# %%
# Sino de esta manera:
df[df['carat']>0.4]['carat']
# Out:
# 64       0.42
# 90       0.70
# 91       0.86
# 92       0.70
# 93       0.71
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 39549, dtype: float64

# %% [markdown]
# Ejercicio 14

# %%
# Filtra filas que son "Premium" o "Ideal"
df[(df['cut'] != 'Premium') & (df['cut'] != 'Ideal')]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94   NaN  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53927   0.79       Good     F     SI1   58.1   59.0   2756  6.06  6.13  3.54
# 53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
#
# [18598 rows x 10 columns]

# %% [markdown]
# Ejercicio 15

# %%
# Estadística descriptiva de la columna "carat"
df['carat'].describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %% [markdown]
# Ejercicio 16

# %%
# Calcula la media de cada columna numérica
print("The mean is :")
print(df.mean())
# Out:
# The mean is :
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734559
# z           3.538734
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# Ejercicio 17

# %%
# Media del precio de cada tipo
df.groupby('cut').price.mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# Ejercicio 18

# %%
# Calcula la cantidad, el mínimo y el máximo precio para cada 'cut'
df.groupby('cut').price.agg(['count', 'min', 'max'])
# Out:
#            count  min    max
# cut
# Fair        1610  337  18574
# Good        4906  327  18788
# Ideal      21551  326  18806
# Premium    13791  326  18823
# Very Good  12082  336  18818

# %% [markdown]
# Ejercicio 19

# %%
# Valores que puede tomar "cut"
print(df['cut'].unique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']

# %% [markdown]
# Ejercicio 20

# %%
# Cuántas veces aparece cada valor de "cut"
df.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# Ejercicio 21

# %%
# Porcentaje de cuántas veces aparece cada valor en "cut"
df['cut'].value_counts(normalize=True) * 100
# Out:
# Ideal        39.953652
# Premium      25.567297
# Very Good    22.398962
# Good          9.095291
# Fair          2.984798
# Name: cut, dtype: float64

# %% [markdown]
# Ejercicio 22

# %%
# Tabla de doble entrada de "cut" y "color"
pd.crosstab(df.cut, df.color)
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %% [markdown]
# Ejercicio 23

# %%
# Histograma de la columna "cut"
# df.cut.plot(kind='hist')
df.cut.hist()

# %% [markdown]
# Ejercicio 24

# %%
# Gráfico de barras de la columna "cut"
# df.cut.plot(kind='hist')
df.cut.hist()

# %% [markdown]
# Ejercicio 25

# %%
# Cuenta el número de missing values de cada columna
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          1
# z          0
# dtype: int64

# %% [markdown]
# Ejercicio 26

# %%
# Número de filas y columnas
df.shape
# Out:
# (53940, 10)

# %%
# Elimina si falta algún valor en una fila
df.dropna(how='any')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53939 rows x 10 columns]

# %% [markdown]
# Ejercicio 27

# %%
# Elimina una fila si faltan todos sus valores
df.dropna(how='all')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# Ejercicio 28

# %%
# Muestra las filas 0, 2, 5 y todas las columnas 
df.loc[(df.index == 0) | (df.index == 2) | (df.index == 5)]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94   NaN  2.48

# %%
# O también así:
df.iloc[[0, 2, 5]]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94   NaN  2.48

# %% [markdown]
# Ejercicio 29

# %%
# Muestra las filas 0 a 2 (inclusive) y las columnas 'color'
df.iloc[[0, 1, 2], [2, 6]]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %%
# Sino también así:
df.head(3)[['color', 'price']]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %% [markdown]
# Ejercicio 30

# %%
# Muestra las filas en las que la 'cut' es 'Premium' más la columna 'color'. 
df.loc[df['cut'] == 'Premium', ['cut', 'color']]
# Out:
#            cut color
# 1      Premium     E
# 3      Premium     I
# 12     Premium     F
# 14     Premium     E
# 15     Premium     E
# ...        ...   ...
# 53928  Premium     E
# 53930  Premium     E
# 53931  Premium     F
# 53934  Premium     D
# 53938  Premium     H
#
# [13791 rows x 2 columns]

# %% [markdown]
# Ejercicio 31

# %%
# Obtiene 5 filas de muestra al azar
df.sample(n = 5)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 17194   1.00    Premium     D     VS2   59.6   60.0   6868  6.57  6.52  3.90
# 2219    0.84  Very Good     D     SI2   63.6   57.0   3145  5.95  6.00  3.80
# 25834   1.71    Premium     H    VVS2   61.4   59.0  14866  7.77  7.67  4.74
# 36850   0.37  Very Good     F     VS2   63.3   56.0    957  4.63  4.56  2.91
# 10790   1.07  Very Good     G     SI1   60.5   62.0   4861  6.60  6.69  4.02

# %% [markdown]
# Ejercicio 32

# %%
# Obtiene una muestra del 75% de las filas sin reemplazarlas
df.sample(frac = .75, random_state = 10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 8018    1.01    Premium     E     SI1   61.7   56.0   4330  6.44  6.39  3.96
# 1583    0.70  Very Good     D     VS1   60.4   58.0   3008  5.71  5.78  3.47
# 9138    1.13  Very Good     H     SI2   59.8   59.0   4537  6.75  6.82  4.06
# 2787    0.76      Ideal     F     VS2   61.0   55.0   3257  5.89  5.92  3.60
# 52429   0.70    Premium     I    VVS1   61.2   59.0   2513  5.65  5.69  3.47
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 5990    0.91      Ideal     I     VS1   62.4   57.0   3954  6.17  6.21  3.86
# 44878   0.50    Premium     G     VS1   58.9   59.0   1629  5.21  5.15  3.05
# 31132   0.31      Ideal     E    VVS2   61.4   58.0    755  4.33  4.37  2.67
# 35166   0.31      Ideal     G      IF   61.4   55.0    891  4.35  4.38  2.68
# 19914   1.51  Very Good     F     SI2   63.2   60.0   8462  7.20  7.27  4.57
#
# [40455 rows x 10 columns]

# %% [markdown]
# Ejercicio 33

# %%
# Cuenta las filas duplicadas (porque los True son en realidad unos entonces si sumas todos te da la cantidad de duplicados)
sum(df.duplicated())
# Out:
# 146
